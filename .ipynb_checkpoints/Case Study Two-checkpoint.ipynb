# %% [markdown]
# __Title:__ Case Study 2: Logistic Regression
# __Authors:__ Will Butler, Robert (Reuven) Derner
# __Date:__ 9/18/23

# %% [markdown]
# ## Business Understanding & Ethical Concerns
#
# The medical community has asked us to examine a study conducted over the past 10 years with patients whom have diabeties. The case study presented to us is to be addressing hospitial readmission rates to minimize patients returning and predict whether a patient will return within 30 days of initial hospitalizaiton. Readmission is a costly endevaor to the hospitial, insurance providers, and to the patients themselves between bills, lost wages, & strain on their respective families.
#
# There is some ethical considering contained within the dataset. We have identified a race category. Given the context of what the results of this study is to be used for would determine the best practice whether to include the feature or to remove it before proceeding with the analysis. Using the feature could be seen as a racial biased in regard to readmittance rates based on what is uncovered. In the case of the study just being utilized by hospitial personal to better treat and forecast patients I would rather have more information than less and would utilize the additional feature. On the other hand, if the catgory is to be used by thrird party vendors for instance, insurance agencies then I would prefer to remove the data point before proceeding with the case study.
#
# Data Source:
#
# Provided by client with metadata dictionary regarding terms

# %%
# Import libraries
import pandas as pd
import seaborn as sns
import numpy as np
from numpy import mean
import matplotlib.pyplot as plt
import random
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio 
from tabulate import tabulate
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix



# Workbook settings
pd.set_option('display.max_columns', None)
random.seed(110)
pio.renderers.default='notebook'

# %%
# Import data from github (next phase)
url = 'https://raw.githubusercontent.com/ReuvenDerner/MSDS_QuantifyingTheWorld/main/diabetic_data.csv'
dia_data_df = pd.read_csv(url, encoding = "utf-8")

# %%
# loacal Import (To be removed later)
#data = pd.read_csv("C:/Users/robert.derner/OneDrive - Flagship Credit Acceptance/Documents/School/Quantifying The World/Case Study Two/diabetic_data.csv")
id_data_maps = pd.read_csv("IDs_mapping.csv")

# %% [markdown]
# ## Data Quality
# Verify data quality: Explain any missing values, duplicate data, and outliers. Are those mistakes? How do you deal with these problems? Give justifications for your methods.

# %%
dia_data_df.shape
# Out:
# (101766, 50)

# %%
id_data_maps.shape
# Out:
# (67, 2)

# %% [markdown]
# ### Examine the data

# %%
dia_data_df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital payer_code         medical_specialty  num_lab_procedures  \
# 0                 1          ?  Pediatrics-Endocrinology                  41
# 1                 3          ?                         ?                  59
# 2                 2          ?                         ?                  11
# 3                 2          ?                         ?                  44
# 4                 1          ?                         ?                  51
#
#    num_procedures  num_medications  number_outpatient  number_emergency  \
# 0               0                1                  0                 0
# 1               0               18                  0                 0
# 2               5               13                  2                 0
# 3               1               16                  0                 0
# 4               0                8                  0                 0
#
#    number_inpatient  diag_1  diag_2 diag_3  number_diagnoses max_glu_serum  \
# 0                 0  250.83       ?      ?                 1          None
# 1                 0     276  250.01    255                 9          None
# 2                 1     648     250    V27                 6          None
# 3                 0       8  250.43    403                 7          None
# 4                 0     197     157    250                 5          None
#
#   A1Cresult metformin repaglinide nateglinide chlorpropamide glimepiride  \
# 0      None        No          No          No             No          No
# 1      None        No          No          No             No          No
# 2      None        No          No          No             No          No
# 3      None        No          No          No             No          No
# 4      None        No          No          No             No          No
#
#   acetohexamide glipizide glyburide tolbutamide pioglitazone rosiglitazone  \
# 0            No        No        No          No           No            No
# 1            No        No        No          No           No            No
# 2            No    Steady        No          No           No            No
# 3            No        No        No          No           No            No
# 4            No    Steady        No          No           No            No
#
#   acarbose miglitol troglitazone tolazamide examide citoglipton insulin  \
# 0       No       No           No         No      No          No      No
# 1       No       No           No         No      No          No      Up
# 2       No       No           No         No      No          No      No
# 3       No       No           No         No      No          No      Up
# 4       No       No           No         No      No          No  Steady
#
#   glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# 0                  No                  No                       No
# 1                  No                  No                       No
# 2                  No                  No                       No
# 3                  No                  No                       No
# 4                  No                  No                       No
#
#   metformin-rosiglitazone metformin-pioglitazone change diabetesMed readmitted
# 0                      No                     No     No          No         NO
# 1                      No                     No     Ch         Yes        >30
# 2                      No                     No     No         Yes         NO
# 3                      No                     No     Ch         Yes         NO
# 4                      No                     No     Ch         Yes         NO

# %%
id_data_maps.head()
# Out:
#   admission_type_id    description
# 0                 1      Emergency
# 1                 2         Urgent
# 2                 3       Elective
# 3                 4        Newborn
# 4                 5  Not Available

# %% [markdown]
# __Missing Values__
# The dataset contains no missing values upon code examination, however there are many "?" contained within the dataset that would indicate missing values. We will have to look more closely at the features to examine the degree of missing data we will need.
#
# For the purposes of classification on the readmittance, we need to investigate further.

# %%
# Features with Null Values and Percent missing
null_df = pd.DataFrame(dia_data_df[dia_data_df.columns[dia_data_df.isnull().any()]].isnull().sum()).reset_index()
null_df.columns = ['Feature', 'Value']
null_df['Percent'] = round((null_df['Value'] / dia_data_df.shape[0] * 100),2)

null_df
# Out:
# Empty DataFrame
# Columns: [Feature, Value, Percent]
# Index: []

# %%
# Replace "?" with Nulls
dia_data_df.replace("?", np.nan, inplace =True)

# %%
# Recheck Nulls
null_df = pd.DataFrame(dia_data_df[dia_data_df.columns[dia_data_df.isnull().any()]].isnull().sum()).reset_index()
null_df.columns = ['Feature', 'Value']
null_df['Percent'] = round((null_df['Value'] / dia_data_df.shape[0] * 100),2)

null_df
# Out:
#              Feature  Value  Percent
# 0               race   2273     2.23
# 1             weight  98569    96.86
# 2         payer_code  40256    39.56
# 3  medical_specialty  49949    49.08
# 4             diag_1     21     0.02
# 5             diag_2    358     0.35
# 6             diag_3   1423     1.40

# %% [markdown]
# After replacing the missing "?"'s with nulls we have a better look at the distribution of missing data across the data. We observe that weight has nearily all of the data missing from the feature, we may as well remove this feature as impuation would be heavily biased if we were to guess a value. The three different diagonsis features we should make sure we one hot encode as there might not be multiple diagnosis per patient. Medicial speciality is not a column where we have metadata for so this may be a feature we decide to imputate, however it is nearly halfway missing so that may be difficult and we could introduce additional biasis into the data. Payer code & race are other columns in which we do not have metadata look up on so these would also be candiates for impuation. We will have to examin each column and see if a pattern emerges with the data.

# %% [markdown]
# __Duplicate Values__
# There are 0 duplicate values in the data set. No action was needed.

# %%
# Duplicate record validation
dia_data_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Explore missing values and response variable

# %%
# Create a bar plot using Matplotlib, including null values
plt.figure(figsize=(8, 6))  # Optional: Set the figure size
dia_data_df['race'].value_counts(dropna=False).plot(kind='bar')
plt.title('Number of Records per Race (Including Nulls)')
plt.xlabel('Race')
plt.ylabel('Count')
plt.show()

# %%
# Get the count of each category, including null values
race_category_counts = dia_data_df['race'].value_counts(dropna=False)
race_category_percentages = (race_category_counts / race_category_counts.sum())*100

#Create a DF to display both counts and percentages
race_df = pd.DataFrame({'Count': race_category_counts, 'Percentage': race_category_percentages})

# Display the result
print(race_df)
# Out:
#                  Count  Percentage
# Caucasian        76099   74.778413
# AfricanAmerican  19210   18.876639
# NaN               2273    2.233555
# Hispanic          2037    2.001651
# Other             1506    1.479866
# Asian              641    0.629876

# %% [markdown]
# We can observe that the vast majority of the patientes within the study are of caucasian, with a little over 2.2% are nulls, we may be able to imputate with caucasian, with the next highest patients observed would be those of African American decesent. The rest of the population is very limited across the study.

# %%
# Create a bar plot using Matplotlib, including null values
plt.figure(figsize=(8, 6))  # Optional: Set the figure size
dia_data_df['payer_code'].value_counts(dropna=False).plot(kind='bar')
plt.title('Number of Records per Payer Code (Including Nulls)')
plt.xlabel('Payer Code')
plt.ylabel('Count')
plt.show()

# %%
# Get the count of each category, including null values
payer_category_counts = dia_data_df['payer_code'].value_counts(dropna=False)
payer_category_percentages = (payer_category_counts / payer_category_counts.sum())*100

#Create a DF to display both counts and percentages
payer_df = pd.DataFrame({'Count': payer_category_counts, 'Percentage': payer_category_percentages})

# Display the result
print(payer_df)
# Out:
#      Count  Percentage
# NaN  40256   39.557416
# MC   32439   31.876069
# HM    6274    6.165124
# SP    5007    4.920111
# BC    4655    4.574219
# MD    3532    3.470707
# CP    2533    2.489043
# UN    2448    2.405519
# CM    1937    1.903386
# OG    1033    1.015074
# PO     592    0.581727
# DM     549    0.539473
# CH     146    0.143466
# WC     135    0.132657
# OT      95    0.093351
# MP      79    0.077629
# SI      55    0.054046
# FR       1    0.000983

# %% [markdown]
# More than half of the feature is missing data, imputation may not be feesable here

# %%
# Create a bar plot using Matplotlib, including null values
plt.figure(figsize=(20, 8))  # Optional: Set the figure size
dia_data_df['medical_specialty'].value_counts(dropna=False).plot(kind='bar')
plt.title('Number of Records per Medical Specialty (Including Nulls)')
plt.xlabel('Medical Specialty')
plt.ylabel('Count')
plt.show()

# %%
# Get the count of each category, including null values
med_category_counts = dia_data_df['medical_specialty'].value_counts(dropna=False)
med_category_percentages = (med_category_counts / med_category_counts.sum())*100

#Create a DF to display both counts and percentages
med_df = pd.DataFrame({'Count': med_category_counts, 'Percentage': med_category_percentages})

# Display the result
print(med_df)
# Out:
#                                   Count  Percentage
# NaN                               49949   49.082208
# InternalMedicine                  14635   14.381031
# Emergency/Trauma                   7565    7.433720
# Family/GeneralPractice             7440    7.310890
# Cardiology                         5352    5.259124
# ...                                 ...         ...
# Perinatology                          1    0.000983
# Proctology                            1    0.000983
# Dermatology                           1    0.000983
# Pediatrics-InfectiousDiseases         1    0.000983
# Surgery-PlasticwithinHeadandNeck      1    0.000983
#
# [73 rows x 2 columns]

# %%
# Get the count of each category, including null values
category_counts = dia_data_df['readmitted'].value_counts(dropna=False)

# Create a pie chart
plt.figure(figsize=(8, 8))  # Optional: Set the figure size
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Readmitted Counts')
plt.show()

# %% [markdown]
# We observe that over half of the paitents who were part of the study were not readmitted while

# %% [markdown]
# __Data Type Conversion__
# In this section we grouped all features by their correct data type and converted each to their coresponding group. This facilitates a much easier analysis into the statistics of each feature type.

# %%
# Features grouped by data type
# cat_features = ['number_of_elements']
# cont_features = ['mean_atomic_mass','wtd_mean_atomic_mass','gmean_atomic_mass','wtd_gmean_atomic_mass',
#                 'entropy_atomic_mass','wtd_entropy_atomic_mass','range_atomic_mass','wtd_range_atomic_mass','std_atomic_mass',
#                 'wtd_std_atomic_mass','mean_fie', 'wtd_mean_fie','gmean_fie','wtd_gmean_fie','entropy_fie','wtd_entropy_fie',
#                 'range_fie','wtd_range_fie','std_fie','wtd_std_fie','mean_atomic_radius','wtd_mean_atomic_radius',
#                 'gmean_atomic_radius','wtd_gmean_atomic_radius','entropy_atomic_radius','wtd_entropy_atomic_radius',
#                 'range_atomic_radius','wtd_range_atomic_radius','std_atomic_radius','wtd_std_atomic_radius','mean_Density',
#                 'wtd_mean_Density','gmean_Density','wtd_gmean_Density','entropy_Density','wtd_entropy_Density','range_Density',
#                 'wtd_range_Density','std_Density','wtd_std_Density','mean_ElectronAffinity','wtd_mean_ElectronAffinity',
#                 'gmean_ElectronAffinity','wtd_gmean_ElectronAffinity','entropy_ElectronAffinity','wtd_entropy_ElectronAffinity',
#                 'range_ElectronAffinity','wtd_range_ElectronAffinity','std_ElectronAffinity','wtd_std_ElectronAffinity',
#                 'mean_FusionHeat','wtd_mean_FusionHeat','gmean_FusionHeat','wtd_gmean_FusionHeat','entropy_FusionHeat',
#                 'wtd_entropy_FusionHeat','range_FusionHeat','wtd_range_FusionHeat','std_FusionHeat','wtd_std_FusionHeat',
#                 'mean_ThermalConductivity','wtd_mean_ThermalConductivity','gmean_ThermalConductivity',
#                 'wtd_gmean_ThermalConductivity','entropy_ThermalConductivity','wtd_entropy_ThermalConductivity',
#                 'range_ThermalConductivity','wtd_range_ThermalConductivity','std_ThermalConductivity',
#                 'wtd_std_ThermalConductivity','mean_Valence','wtd_mean_Valence','gmean_Valence','wtd_gmean_Valence',
#                 'entropy_Valence','wtd_entropy_Valence','range_Valence','wtd_range_Valence','std_Valence','wtd_std_Valence']

# %%
# Features converted to corresponding group type (may be interesting to convert to string)
# data[cat_features] = data[cat_features].astype("string")

# %% [markdown]
# ## Visualize Attributes

# %%
# Create a heatmap using Seaborn
plt.figure(figsize=(8, 6))  # Optional: Set the figure size
heatmap_data = pd.crosstab(dia_data_df['readmitted'], dia_data_df['gender'])
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Heatmap of Gender vs. Readmitted')
plt.xlabel('Gender')
plt.ylabel('Readmitted')
plt.show()

# %% [markdown]
# Above we see a heatmat analyzing the gender compared to our response variable readmitted. The study shows a distribution among the feature and our response indicating no clear pattern among genders. The few outliers we see can likely be removed from the dataset entirely prior to modeling.

# %%
# Set a larger figure size
plt.figure(figsize=(10, 6))  # Optional: Set the figure size

# Create a box plot for each readmission status
boxplot_data = [dia_data_df[dia_data_df['readmitted'] == status]['admission_type_id']
               for status in dia_data_df['readmitted'].unique()]

plt.boxplot(boxplot_data, labels=dia_data_df['readmitted'].unique(), showfliers=True) 
plt.title('Box Plot of Admission Type by Readmission Status')
plt.xlabel('Readmission Status')
plt.ylabel('Admission Type')
plt.show()

# %%
# Create a crosstab to calculate frequencies
cross_tab = pd.crosstab(dia_data_df['readmitted'], dia_data_df['admission_type_id'])

# Create a bivariate histogram-like heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cross_tab, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Bivariate Histogram-Like Heatmap of Admission Type by Readmission Status')
plt.xlabel('Admission Type')
plt.ylabel('Readmission Status')
plt.show()

# %% [markdown]
# The box and whisker plot indicates a very uniform distribution among each of the type's of admission type ids'. There is some notable outliers among those with no readmittance from admission type 8 or Not Mapped. The bulk of the data is coming admission type 1, 2, and 3 (Emergency, Urgent, or Elective) respectively. Diving in we see a very limited population for admissions type 4, 7 & 8 (Newborns, Trauma Center, & Not Mapped).

# %% [markdown]
# ## Explore Correlations

# %%
# First step to explore any relationships between data would be to do a correlation
dia_data_df.corr()
# Out:
#                           encounter_id  patient_nbr  admission_type_id  \
# encounter_id                  1.000000     0.512028          -0.158961
# patient_nbr                   0.512028     1.000000          -0.011128
# admission_type_id            -0.158961    -0.011128           1.000000
# discharge_disposition_id     -0.132876    -0.136814           0.083483
# admission_source_id          -0.112402    -0.032568           0.106654
# time_in_hospital             -0.062221    -0.024092          -0.012500
# num_lab_procedures           -0.026062     0.015946          -0.143713
# num_procedures               -0.014225    -0.015570           0.129888
# num_medications               0.076113     0.020665           0.079535
# number_outpatient             0.103756     0.103379           0.026511
# number_emergency              0.082803     0.062352          -0.019116
# number_inpatient              0.030962     0.012480          -0.038161
# number_diagnoses              0.265149     0.226847          -0.117126
#
#                           discharge_disposition_id  admission_source_id  \
# encounter_id                             -0.132876            -0.112402
# patient_nbr                              -0.136814            -0.032568
# admission_type_id                         0.083483             0.106654
# discharge_disposition_id                  1.000000             0.018193
# admission_source_id                       0.018193             1.000000
# time_in_hospital                          0.162748            -0.006965
# num_lab_procedures                        0.023415             0.048885
# num_procedures                            0.015921            -0.135400
# num_medications                           0.108753            -0.054533
# number_outpatient                        -0.008715             0.027244
# number_emergency                         -0.024471             0.059892
# number_inpatient                          0.020787             0.036314
# number_diagnoses                          0.046891             0.072114
#
#                           time_in_hospital  num_lab_procedures  \
# encounter_id                     -0.062221           -0.026062
# patient_nbr                      -0.024092            0.015946
# admission_type_id                -0.012500           -0.143713
# discharge_disposition_id          0.162748            0.023415
# admission_source_id              -0.006965            0.048885
# time_in_hospital                  1.000000            0.318450
# num_lab_procedures                0.318450            1.000000
# num_procedures                    0.191472            0.058066
# num_medications                   0.466135            0.268161
# number_outpatient                -0.008916           -0.007602
# number_emergency                 -0.009681           -0.002279
# number_inpatient                  0.073623            0.039231
# number_diagnoses                  0.220186            0.152773
#
#                           num_procedures  num_medications  number_outpatient  \
# encounter_id                   -0.014225         0.076113           0.103756
# patient_nbr                    -0.015570         0.020665           0.103379
# admission_type_id               0.129888         0.079535           0.026511
# discharge_disposition_id        0.015921         0.108753          -0.008715
# admission_source_id            -0.135400        -0.054533           0.027244
# time_in_hospital                0.191472         0.466135          -0.008916
# num_lab_procedures              0.058066         0.268161          -0.007602
# num_procedures                  1.000000         0.385767          -0.024819
# num_medications                 0.385767         1.000000           0.045197
# number_outpatient              -0.024819         0.045197           1.000000
# number_emergency               -0.038179         0.013180           0.091459
# number_inpatient               -0.066236         0.064194           0.107338
# number_diagnoses                0.073734         0.261526           0.094152
#
#                           number_emergency  number_inpatient  number_diagnoses
# encounter_id                      0.082803          0.030962          0.265149
# patient_nbr                       0.062352          0.012480          0.226847
# admission_type_id                -0.019116         -0.038161         -0.117126
# discharge_disposition_id         -0.024471          0.020787          0.046891
# admission_source_id               0.059892          0.036314          0.072114
# time_in_hospital                 -0.009681          0.073623          0.220186
# num_lab_procedures               -0.002279          0.039231          0.152773
# num_procedures                   -0.038179         -0.066236          0.073734
# num_medications                   0.013180          0.064194          0.261526
# number_outpatient                 0.091459          0.107338          0.094152
# number_emergency                  1.000000          0.266559          0.055539
# number_inpatient                  0.266559          1.000000          0.104710
# number_diagnoses                  0.055539          0.104710          1.000000

# %% [markdown]
# ### Dropping null records

# %%
# Before imputation, we need to impuate some of the missing data, or remove columns containing nulls 
# race
# weight
# payer_code
# medical_specialty
# diag_1
# diag_2
# diag_3

# List of columns to drop for purposes of correlation 
columns_to_drop = ['weight', 'medical_specialty','payer_code']

# Drop the specified columns
refined_df = dia_data_df.drop(columns=columns_to_drop)

# %% [markdown]
# ### Imputation

# %%
imp_df = refined_df

# %%
# for imputation on new df
fill_value_race = 'Caucasian'
fill_value_diag1 = '?'
fill_value_diag2 = '?'
fill_value_diag3 = '?'

imp_df['race'].fillna(fill_value_race, inplace=True)
imp_df['diag_1'].fillna(fill_value_diag1, inplace=True)
imp_df['diag_2'].fillna(fill_value_diag2, inplace=True)
imp_df['diag_3'].fillna(fill_value_diag3, inplace=True)

# %%
imp_df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0       2278392      8222157        Caucasian  Female   [0-10)
# 1        149190     55629189        Caucasian  Female  [10-20)
# 2         64410     86047875  AfricanAmerican  Female  [20-30)
# 3        500364     82442376        Caucasian    Male  [30-40)
# 4         16680     42519267        Caucasian    Male  [40-50)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 0                 1                  41               0                1
# 1                 3                  59               0               18
# 2                 2                  11               5               13
# 3                 2                  44               1               16
# 4                 1                  51               0                8
#
#    number_outpatient  number_emergency  number_inpatient  diag_1  diag_2  \
# 0                  0                 0                 0  250.83       ?
# 1                  0                 0                 0     276  250.01
# 2                  2                 0                 1     648     250
# 3                  0                 0                 0       8  250.43
# 4                  0                 0                 0     197     157
#
#   diag_3  number_diagnoses max_glu_serum A1Cresult metformin repaglinide  \
# 0      ?                 1          None      None        No          No
# 1    255                 9          None      None        No          No
# 2    V27                 6          None      None        No          No
# 3    403                 7          None      None        No          No
# 4    250                 5          None      None        No          No
#
#   nateglinide chlorpropamide glimepiride acetohexamide glipizide glyburide  \
# 0          No             No          No            No        No        No
# 1          No             No          No            No        No        No
# 2          No             No          No            No    Steady        No
# 3          No             No          No            No        No        No
# 4          No             No          No            No    Steady        No
#
#   tolbutamide pioglitazone rosiglitazone acarbose miglitol troglitazone  \
# 0          No           No            No       No       No           No
# 1          No           No            No       No       No           No
# 2          No           No            No       No       No           No
# 3          No           No            No       No       No           No
# 4          No           No            No       No       No           No
#
#   tolazamide examide citoglipton insulin glyburide-metformin  \
# 0         No      No          No      No                  No
# 1         No      No          No      Up                  No
# 2         No      No          No      No                  No
# 3         No      No          No      Up                  No
# 4         No      No          No  Steady                  No
#
#   glipizide-metformin glimepiride-pioglitazone metformin-rosiglitazone  \
# 0                  No                       No                      No
# 1                  No                       No                      No
# 2                  No                       No                      No
# 3                  No                       No                      No
# 4                  No                       No                      No
#
#   metformin-pioglitazone change diabetesMed readmitted
# 0                     No     No          No         NO
# 1                     No     Ch         Yes        >30
# 2                     No     No         Yes         NO
# 3                     No     Ch         Yes         NO
# 4                     No     Ch         Yes         NO

# %%
# Recheck Nulls
null_df = pd.DataFrame(imp_df[imp_df.columns[imp_df.isnull().any()]].isnull().sum()).reset_index()
null_df.columns = ['Feature', 'Value']
null_df['Percent'] = round((null_df['Value'] / imp_df.shape[0] * 100),2)

null_df
# Out:
# Empty DataFrame
# Columns: [Feature, Value, Percent]
# Index: []

# %% [markdown]
# all nulls have been removed from the dataset

# %% [markdown]
# ### Encoding

# %%
# Perform one-hot encoding
encoded_df = pd.get_dummies(imp_df, columns=['race','gender','age','admission_type_id','discharge_disposition_id',
                                                  'admission_source_id',
                                             #'payer_code','medical_specialty', 'weight',''
                                                  'num_lab_procedures','num_procedures','num_medications','number_outpatient',
                                                  'number_emergency','number_inpatient','diag_1','diag_2','diag_3',
                                                  'number_diagnoses','max_glu_serum','A1Cresult','metformin','repaglinide',
                                                  'nateglinide','chlorpropamide','glimepiride','acetohexamide','glipizide',
                                                  'glyburide','tolbutamide','pioglitazone','rosiglitazone','acarbose',
                                                  'miglitol','troglitazone','tolazamide','examide','citoglipton','insulin',
                                                  'glyburide-metformin','glipizide-metformin','glimepiride-pioglitazone',
                                                  'metformin-rosiglitazone','metformin-pioglitazone','change','diabetesMed',
                                                  'readmitted'])

# %%
# First step to explore any relationships between data would be to do a correlation
correlations = encoded_df.corr()

# %%
correlations
# Out:
#                       encounter_id  patient_nbr  time_in_hospital  \
# encounter_id              1.000000     0.512028         -0.062221
# patient_nbr               0.512028     1.000000         -0.024092
# time_in_hospital         -0.062221    -0.024092          1.000000
# race_AfricanAmerican     -0.094322    -0.136956          0.018078
# race_Asian                0.030217     0.040530         -0.010686
# ...                            ...          ...               ...
# diabetesMed_No           -0.051817    -0.017232         -0.062520
# diabetesMed_Yes           0.051817     0.017232          0.062520
# readmitted_<30           -0.008519     0.007893          0.044199
# readmitted_>30           -0.034384     0.072256          0.024434
# readmitted_NO             0.038267    -0.074093         -0.051289
#
#                       race_AfricanAmerican  race_Asian  race_Caucasian  \
# encounter_id                     -0.094322    0.030217        0.066962
# patient_nbr                      -0.136956    0.040530        0.091056
# time_in_hospital                  0.018078   -0.010686       -0.008006
# race_AfricanAmerican              1.000000   -0.038405       -0.882912
# race_Asian                       -0.038405    1.000000       -0.145723
# ...                                    ...         ...             ...
# diabetesMed_No                   -0.000340    0.005487        0.001548
# diabetesMed_Yes                   0.000340   -0.005487       -0.001548
# readmitted_<30                    0.000892   -0.002578        0.002503
# readmitted_>30                   -0.003987   -0.016385        0.014113
# readmitted_NO                     0.003250    0.017299       -0.015079
#
#                       race_Hispanic  race_Other  gender_Female  gender_Male  \
# encounter_id               0.013427    0.036972      -0.006009     0.005992
# patient_nbr                0.026650    0.069093      -0.006656     0.006617
# time_in_hospital          -0.016091   -0.005026       0.029911    -0.029890
# race_AfricanAmerican      -0.068940   -0.059120       0.070559    -0.070531
# race_Asian                -0.011378   -0.009758      -0.006625     0.006629
# ...                             ...         ...            ...          ...
# diabetesMed_No             0.002927   -0.011281       0.015918    -0.015932
# diabetesMed_Yes           -0.002927    0.011281      -0.015918     0.015932
# readmitted_<30            -0.003415   -0.005962       0.002919    -0.002898
# readmitted_>30            -0.010226   -0.013659       0.016929    -0.016886
# readmitted_NO              0.011938    0.016830      -0.018035     0.017980
#
#                       gender_Unknown/Invalid  age_[0-10)  age_[10-20)  \
# encounter_id                        0.001539   -0.035857    -0.038612
# patient_nbr                         0.003571   -0.027196    -0.034130
# time_in_hospital                   -0.001933   -0.024662    -0.033376
# race_AfricanAmerican               -0.002619   -0.009093     0.024023
# race_Asian                         -0.000432    0.003081    -0.003558
# ...                                      ...         ...          ...
# diabetesMed_No                      0.001334   -0.005303    -0.019310
# diabetesMed_Yes                    -0.001334    0.005303     0.019310
# readmitted_<30                     -0.001924   -0.011753    -0.014104
# readmitted_>30                     -0.003978   -0.015680    -0.004356
# readmitted_NO                       0.005020    0.022421     0.013075
#
#                       age_[20-30)  age_[30-40)  age_[40-50)  age_[50-60)  \
# encounter_id            -0.006851    -0.022480    -0.026721    -0.019668
# patient_nbr             -0.014677    -0.023164    -0.017983    -0.025828
# time_in_hospital        -0.035820    -0.039205    -0.038714    -0.040907
# race_AfricanAmerican     0.045082     0.067816     0.082046     0.064753
# race_Asian              -0.004355    -0.005769    -0.003811     0.004736
# ...                           ...          ...          ...          ...
# diabetesMed_No          -0.007207     0.007150     0.004198    -0.007053
# diabetesMed_Yes          0.007207    -0.007150    -0.004198     0.007053
# readmitted_<30           0.012596     0.000448    -0.005726    -0.021436
# readmitted_>30          -0.011198    -0.014346    -0.007361    -0.006053
# readmitted_NO            0.002754     0.013437     0.010657     0.019330
#
#                       age_[60-70)  age_[70-80)  age_[80-90)  age_[90-100)  \
# encounter_id             0.010811    -0.011287     0.054864      0.029474
# patient_nbr              0.003027    -0.002140     0.057397      0.019939
# time_in_hospital        -0.002452     0.038313     0.062336      0.020250
# race_AfricanAmerican    -0.000728    -0.063553    -0.095770     -0.028008
# race_Asian               0.005504     0.004497    -0.006072     -0.005012
# ...                           ...          ...          ...           ...
# diabetesMed_No          -0.016795    -0.006303     0.020453      0.029543
# diabetesMed_Yes          0.016795     0.006303    -0.020453     -0.029543
# readmitted_<30          -0.000533     0.011427     0.013227     -0.000324
# readmitted_>30           0.002191     0.017468     0.011903     -0.021137
# readmitted_NO           -0.001759    -0.023925    -0.019739      0.020421
#
#                       admission_type_id_1  admission_type_id_2  \
# encounter_id                     0.099038            -0.030776
# patient_nbr                     -0.004016             0.037034
# time_in_hospital                -0.006308             0.033884
# race_AfricanAmerican             0.113990            -0.043407
# race_Asian                      -0.017439             0.021779
# ...                                   ...                  ...
# diabetesMed_No                   0.014411            -0.017737
# diabetesMed_Yes                 -0.014411             0.017737
# readmitted_<30                   0.012241             0.000295
# readmitted_>30                   0.018638            -0.000146
# readmitted_NO                   -0.025558            -0.000047
#
#                       admission_type_id_3  admission_type_id_4  \
# encounter_id                     0.048230            -0.002114
# patient_nbr                     -0.012247            -0.004910
# time_in_hospital                -0.012069            -0.003972
# race_AfricanAmerican            -0.048966             0.000285
# race_Asian                       0.000047             0.011741
# ...                                   ...                  ...
# diabetesMed_No                  -0.004643            -0.000706
# diabetesMed_Yes                  0.004643             0.000706
# readmitted_<30                  -0.011625            -0.000365
# readmitted_>30                  -0.044794            -0.003104
# readmitted_NO                    0.050185             0.003200
#
#                       admission_type_id_5  admission_type_id_6  \
# encounter_id                    -0.118975            -0.142566
# patient_nbr                     -0.063877             0.019895
# time_in_hospital                -0.033400             0.014677
# race_AfricanAmerican            -0.058987            -0.039108
# race_Asian                      -0.011817             0.013244
# ...                                   ...                  ...
# diabetesMed_No                  -0.022658             0.030737
# diabetesMed_Yes                  0.022658            -0.030737
# readmitted_<30                  -0.005750            -0.000629
# readmitted_>30                   0.004838             0.035553
# readmitted_NO                   -0.000995            -0.033607
#
#                       admission_type_id_7  admission_type_id_8  \
# encounter_id                     0.012649             0.006588
# patient_nbr                      0.012230             0.026157
# time_in_hospital                 0.002219            -0.025089
# race_AfricanAmerican            -0.003434             0.001612
# race_Asian                      -0.001144            -0.004472
# ...                                   ...                  ...
# diabetesMed_No                   0.001903            -0.010673
# diabetesMed_Yes                 -0.001903             0.010673
# readmitted_<30                  -0.005092            -0.004856
# readmitted_>30                  -0.010526            -0.010224
# readmitted_NO                    0.013283             0.012845
#
#                       discharge_disposition_id_1  discharge_disposition_id_2  \
# encounter_id                            0.027017                    0.005285
# patient_nbr                             0.005932                    0.033769
# time_in_hospital                       -0.280528                   -0.026104
# race_AfricanAmerican                    0.047048                   -0.033817
# race_Asian                              0.017842                    0.010066
# ...                                          ...                         ...
# diabetesMed_No                         -0.007409                    0.015606
# diabetesMed_Yes                         0.007409                   -0.015606
# readmitted_<30                         -0.071121                    0.022796
# readmitted_>30                          0.020062                   -0.010843
# readmitted_NO                           0.025738                   -0.004029
#
#                       discharge_disposition_id_3  discharge_disposition_id_4  \
# encounter_id                            0.065033                   -0.016677
# patient_nbr                             0.058062                   -0.005546
# time_in_hospital                        0.185711                    0.028891
# race_AfricanAmerican                   -0.056799                    0.012722
# race_Asian                             -0.007905                   -0.005760
# ...                                          ...                         ...
# diabetesMed_No                         -0.019007                    0.006962
# diabetesMed_Yes                         0.019007                   -0.006962
# readmitted_<30                          0.044343                    0.004568
# readmitted_>30                          0.002524                   -0.001541
# readmitted_NO                          -0.030425                   -0.001412
#
#                       discharge_disposition_id_5  discharge_disposition_id_6  \
# encounter_id                           -0.071650                    0.047440
# patient_nbr                            -0.038203                    0.071629
# time_in_hospital                        0.045621                    0.132860
# race_AfricanAmerican                    0.000586                   -0.021468
# race_Asian                             -0.001688                   -0.012045
# ...                                          ...                         ...
# diabetesMed_No                          0.004729                   -0.025059
# diabetesMed_Yes                        -0.004729                    0.025059
# readmitted_<30                          0.033429                    0.018585
# readmitted_>30                         -0.012215                    0.053000
# readmitted_NO                          -0.009434                   -0.062430
#
#                       discharge_disposition_id_7  discharge_disposition_id_8  \
# encounter_id                            0.006942                   -0.025914
# patient_nbr                             0.013898                   -0.025046
# time_in_hospital                       -0.040923                    0.026715
# race_AfricanAmerican                    0.008498                   -0.001841
# race_Asian                             -0.001472                   -0.002595
# ...                                          ...                         ...
# diabetesMed_No                          0.008301                    0.002269
# diabetesMed_Yes                        -0.008301                   -0.002269
# readmitted_<30                          0.008191                    0.002825
# readmitted_>30                          0.000898                    0.000176
# readmitted_NO                          -0.006033                   -0.001953
#
#                       discharge_disposition_id_9  discharge_disposition_id_10  \
# encounter_id                            0.007040                    -0.011679
# patient_nbr                             0.005164                     0.001593
# time_in_hospital                        0.001074                     0.004555
# race_AfricanAmerican                   -0.005182                    -0.003704
# race_Asian                             -0.001144                    -0.000611
# ...                                          ...                          ...
# diabetesMed_No                         -0.004600                    -0.001155
# diabetesMed_Yes                         0.004600                     0.001155
# readmitted_<30                          0.014462                    -0.002722
# readmitted_>30                         -0.007656                     0.005112
# readmitted_NO                          -0.001814                    -0.003170
#
#                       discharge_disposition_id_11  \
# encounter_id                            -0.007957
# patient_nbr                              0.004378
# time_in_hospital                         0.017108
# race_AfricanAmerican                     0.002401
# race_Asian                              -0.002309
# ...                                           ...
# diabetesMed_No                           0.033247
# diabetesMed_Yes                         -0.033247
# readmitted_<30                          -0.045388
# readmitted_>30                          -0.093823
# readmitted_NO                            0.118405
#
#                       discharge_disposition_id_12  \
# encounter_id                            -0.005730
# patient_nbr                             -0.002830
# time_in_hospital                        -0.001327
# race_AfricanAmerican                    -0.002619
# race_Asian                              -0.000432
# ...                                           ...
# diabetesMed_No                           0.009935
# diabetesMed_Yes                         -0.009935
# readmitted_<30                           0.009571
# readmitted_>30                          -0.003978
# readmitted_NO                           -0.002242
#
#                       discharge_disposition_id_13  \
# encounter_id                             0.032771
# patient_nbr                              0.014596
# time_in_hospital                         0.032553
# race_AfricanAmerican                     0.001480
# race_Asian                               0.002955
# ...                                           ...
# diabetesMed_No                           0.007190
# diabetesMed_Yes                         -0.007190
# readmitted_<30                          -0.012748
# readmitted_>30                          -0.034092
# readmitted_NO                            0.040659
#
#                       discharge_disposition_id_14  \
# encounter_id                             0.018877
# patient_nbr                              0.003590
# time_in_hospital                         0.021911
# race_AfricanAmerican                    -0.013823
# race_Asian                              -0.004822
# ...                                           ...
# diabetesMed_No                           0.008300
# diabetesMed_Yes                         -0.008300
# readmitted_<30                          -0.009057
# readmitted_>30                          -0.041986
# readmitted_NO                            0.045878
#
#                       discharge_disposition_id_15  \
# encounter_id                             0.000329
# patient_nbr                              0.007045
# time_in_hospital                         0.016682
# race_AfricanAmerican                     0.007176
# race_Asian                              -0.001982
# ...                                           ...
# diabetesMed_No                          -0.006091
# diabetesMed_Yes                          0.006091
# readmitted_<30                           0.026309
# readmitted_>30                          -0.003319
# readmitted_NO                           -0.013445
#
#                       discharge_disposition_id_16  \
# encounter_id                            -0.008568
# patient_nbr                             -0.008016
# time_in_hospital                        -0.001379
# race_AfricanAmerican                     0.004646
# race_Asian                              -0.000828
# ...                                           ...
# diabetesMed_No                          -0.005682
# diabetesMed_Yes                          0.005682
# readmitted_<30                          -0.003685
# readmitted_>30                           0.004278
# readmitted_NO                           -0.001764
#
#                       discharge_disposition_id_17  \
# encounter_id                            -0.009924
# patient_nbr                             -0.009001
# time_in_hospital                         0.006022
# race_AfricanAmerican                     0.002906
# race_Asian                              -0.000934
# ...                                           ...
# diabetesMed_No                          -0.002428
# diabetesMed_Yes                          0.002428
# readmitted_<30                          -0.004157
# readmitted_>30                           0.000193
# readmitted_NO                            0.002441
#
#                       discharge_disposition_id_18  \
# encounter_id                            -0.208716
# patient_nbr                             -0.224709
# time_in_hospital                         0.054889
# race_AfricanAmerican                     0.035225
# race_Asian                              -0.006809
# ...                                           ...
# diabetesMed_No                           0.069842
# diabetesMed_Yes                         -0.069842
# readmitted_<30                           0.007860
# readmitted_>30                          -0.028906
# readmitted_NO                            0.022682
#
#                       discharge_disposition_id_19  \
# encounter_id                             0.004646
# patient_nbr                              0.007044
# time_in_hospital                        -0.007488
# race_AfricanAmerican                    -0.004277
# race_Asian                               0.013303
# ...                                           ...
# diabetesMed_No                           0.005690
# diabetesMed_Yes                         -0.005690
# readmitted_<30                          -0.003143
# readmitted_>30                          -0.006496
# readmitted_NO                            0.008198
#
#                       discharge_disposition_id_20  \
# encounter_id                            -0.002674
# patient_nbr                              0.000809
# time_in_hospital                         0.000154
# race_AfricanAmerican                    -0.002138
# race_Asian                              -0.000353
# ...                                           ...
# diabetesMed_No                          -0.002423
# diabetesMed_Yes                          0.002423
# readmitted_<30                          -0.001571
# readmitted_>30                          -0.003248
# readmitted_NO                            0.004099
#
#                       discharge_disposition_id_22  \
# encounter_id                             0.036125
# patient_nbr                              0.022688
# time_in_hospital                         0.065967
# race_AfricanAmerican                    -0.003481
# race_Asian                              -0.002289
# ...                                           ...
# diabetesMed_No                          -0.018255
# diabetesMed_Yes                          0.018255
# readmitted_<30                           0.074228
# readmitted_>30                          -0.026346
# readmitted_NO                           -0.021691
#
#                       discharge_disposition_id_23  \
# encounter_id                             0.006633
# patient_nbr                             -0.006026
# time_in_hospital                         0.056862
# race_AfricanAmerican                     0.018677
# race_Asian                              -0.005076
# ...                                           ...
# diabetesMed_No                          -0.012410
# diabetesMed_Yes                          0.012410
# readmitted_<30                          -0.007853
# readmitted_>30                           0.000031
# readmitted_NO                            0.004931
#
#                       discharge_disposition_id_24  \
# encounter_id                             0.015460
# patient_nbr                             -0.004049
# time_in_hospital                        -0.003336
# race_AfricanAmerican                    -0.003540
# race_Asian                              -0.001730
# ...                                           ...
# diabetesMed_No                           0.001034
# diabetesMed_Yes                         -0.001034
# readmitted_<30                           0.002362
# readmitted_>30                          -0.000727
# readmitted_NO                           -0.000797
#
#                       discharge_disposition_id_25  \
# encounter_id                            -0.122082
# patient_nbr                             -0.103872
# time_in_hospital                        -0.003276
# race_AfricanAmerican                    -0.002992
# race_Asian                              -0.001557
# ...                                           ...
# diabetesMed_No                          -0.001295
# diabetesMed_Yes                          0.001295
# readmitted_<30                          -0.005844
# readmitted_>30                           0.006421
# readmitted_NO                           -0.002449
#
#                       discharge_disposition_id_27  \
# encounter_id                             0.002352
# patient_nbr                             -0.003977
# time_in_hospital                         0.007993
# race_AfricanAmerican                     0.003784
# race_Asian                              -0.000558
# ...                                           ...
# diabetesMed_No                           0.002832
# diabetesMed_Yes                         -0.002832
# readmitted_<30                          -0.002484
# readmitted_>30                          -0.002195
# readmitted_NO                            0.003669
#
#                       discharge_disposition_id_28  admission_source_id_1  \
# encounter_id                             0.013680               0.021264
# patient_nbr                              0.014160              -0.017609
# time_in_hospital                        -0.006956              -0.029622
# race_AfricanAmerican                    -0.000162              -0.045956
# race_Asian                              -0.002944              -0.002797
# ...                                           ...                    ...
# diabetesMed_No                          -0.003772              -0.003139
# diabetesMed_Yes                          0.003772               0.003139
# readmitted_<30                           0.029987              -0.011646
# readmitted_>30                          -0.008120              -0.031168
# readmitted_NO                           -0.011176               0.037166
#
#                       admission_source_id_2  admission_source_id_3  \
# encounter_id                      -0.086172              -0.038395
# patient_nbr                        0.010897              -0.036359
# time_in_hospital                   0.010132               0.006145
# race_AfricanAmerican               0.035295              -0.007798
# race_Asian                        -0.007139              -0.000516
# ...                                     ...                    ...
# diabetesMed_No                     0.000702               0.007631
# diabetesMed_Yes                   -0.000702              -0.007631
# readmitted_<30                    -0.003677               0.005925
# readmitted_>30                    -0.015044              -0.003521
# readmitted_NO                      0.016711              -0.000375
#
#                       admission_source_id_4  admission_source_id_5  \
# encounter_id                      -0.082376              -0.015750
# patient_nbr                       -0.068434              -0.028156
# time_in_hospital                   0.085446               0.044196
# race_AfricanAmerican              -0.017531               0.027678
# race_Asian                        -0.005045              -0.003246
# ...                                     ...                    ...
# diabetesMed_No                    -0.001597               0.027727
# diabetesMed_Yes                    0.001597              -0.027727
# readmitted_<30                    -0.008362               0.001909
# readmitted_>30                    -0.052207              -0.014144
# readmitted_NO                      0.055214               0.012322
#
#                       admission_source_id_6  admission_source_id_7  \
# encounter_id                      -0.075566               0.158204
# patient_nbr                       -0.142166               0.139335
# time_in_hospital                   0.001529              -0.003233
# race_AfricanAmerican               0.040970               0.061240
# race_Asian                        -0.009483               0.015999
# ...                                     ...                    ...
# diabetesMed_No                    -0.005961               0.001657
# diabetesMed_Yes                    0.005961              -0.001657
# readmitted_<30                    -0.008604               0.019119
# readmitted_>30                    -0.054891               0.065914
# readmitted_NO                      0.057934              -0.075118
#
#                       admission_source_id_8  admission_source_id_9  \
# encounter_id                       0.001944              -0.017297
# patient_nbr                        0.004578              -0.037835
# time_in_hospital                   0.004900              -0.011513
# race_AfricanAmerican              -0.000041              -0.001144
# race_Asian                        -0.000998              -0.002792
# ...                                     ...                    ...
# diabetesMed_No                    -0.004990              -0.009831
# diabetesMed_Yes                    0.004990               0.009831
# readmitted_<30                     0.000534              -0.000846
# readmitted_>30                    -0.002611              -0.016277
# readmitted_NO                      0.002160               0.016102
#
#                       admission_source_id_10  admission_source_id_11  \
# encounter_id                        0.002341                0.004374
# patient_nbr                         0.002018                0.001714
# time_in_hospital                   -0.000062               -0.002816
# race_AfricanAmerican               -0.004277                0.003526
# race_Asian                         -0.000706               -0.000353
# ...                                      ...                     ...
# diabetesMed_No                     -0.004846               -0.002423
# diabetesMed_Yes                     0.004846                0.002423
# readmitted_<30                     -0.003143               -0.001571
# readmitted_>30                     -0.001846               -0.003248
# readmitted_NO                       0.003751                0.004099
#
#                       admission_source_id_13  admission_source_id_14  \
# encounter_id                        0.006802                0.000898
# patient_nbr                         0.000335               -0.002358
# time_in_hospital                   -0.001466               -0.002073
# race_AfricanAmerican               -0.001512                0.009190
# race_Asian                         -0.000250               -0.000353
# ...                                      ...                     ...
# diabetesMed_No                     -0.001713                0.002845
# diabetesMed_Yes                     0.001713               -0.002845
# readmitted_<30                     -0.001111               -0.001571
# readmitted_>30                     -0.002297               -0.003248
# readmitted_NO                       0.002898                0.004099
#
#                       admission_source_id_17  admission_source_id_20  \
# encounter_id                       -0.192527               -0.057414
# patient_nbr                        -0.094634               -0.011313
# time_in_hospital                   -0.021505                0.002422
# race_AfricanAmerican               -0.070486               -0.017306
# race_Asian                         -0.012806               -0.000044
# ...                                      ...                     ...
# diabetesMed_No                     -0.000975               -0.010003
# diabetesMed_Yes                     0.000975                0.010003
# readmitted_<30                     -0.006351                0.003166
# readmitted_>30                      0.007399                0.012844
# readmitted_NO                      -0.003064               -0.014284
#
#                       admission_source_id_22  admission_source_id_25  \
# encounter_id                        0.017085                0.009376
# patient_nbr                         0.007316                0.005704
# time_in_hospital                    0.020387                0.002382
# race_AfricanAmerican               -0.002926               -0.002138
# race_Asian                         -0.000865               -0.000353
# ...                                      ...                     ...
# diabetesMed_No                     -0.005935               -0.002423
# diabetesMed_Yes                     0.005935                0.002423
# readmitted_<30                      0.001899               -0.001571
# readmitted_>30                     -0.002262               -0.003248
# readmitted_NO                       0.000963                0.004099
#
#                       num_lab_procedures_1  num_lab_procedures_2  \
# encounter_id                      0.076843              0.033489
# patient_nbr                       0.066727              0.022803
# time_in_hospital                 -0.071221             -0.032456
# race_AfricanAmerican             -0.022500             -0.010397
# race_Asian                        0.009805             -0.003524
# ...                                    ...                   ...
# diabetesMed_No                   -0.012795             -0.000721
# diabetesMed_Yes                   0.012795              0.000721
# readmitted_<30                   -0.010004              0.000944
# readmitted_>30                   -0.013506              0.009452
# readmitted_NO                     0.019237             -0.009637
#
#                       num_lab_procedures_3  num_lab_procedures_4  \
# encounter_id                      0.031056              0.020308
# patient_nbr                       0.021800              0.021908
# time_in_hospital                 -0.038340             -0.037159
# race_AfricanAmerican             -0.014334             -0.008402
# race_Asian                       -0.000319             -0.000778
# ...                                    ...                   ...
# diabetesMed_No                    0.002423              0.000795
# diabetesMed_Yes                  -0.002423             -0.000795
# readmitted_<30                   -0.004463             -0.009329
# readmitted_>30                    0.000939              0.003717
# readmitted_NO                     0.001921              0.002337
#
#                       num_lab_procedures_5  num_lab_procedures_6  \
# encounter_id                      0.017678              0.015114
# patient_nbr                       0.014450              0.017545
# time_in_hospital                 -0.025200             -0.029474
# race_AfricanAmerican             -0.011378             -0.012053
# race_Asian                        0.000466             -0.004197
# ...                                    ...                   ...
# diabetesMed_No                   -0.006957              0.002731
# diabetesMed_Yes                   0.006957             -0.002731
# readmitted_<30                   -0.002899             -0.006216
# readmitted_>30                   -0.003852             -0.002156
# readmitted_NO                     0.005516              0.005988
#
#                       num_lab_procedures_7  num_lab_procedures_8  \
# encounter_id                      0.018817             -0.005265
# patient_nbr                       0.025567              0.015460
# time_in_hospital                 -0.024457             -0.024742
# race_AfricanAmerican             -0.008916             -0.013041
# race_Asian                        0.002132              0.003516
# ...                                    ...                   ...
# diabetesMed_No                    0.007356              0.006176
# diabetesMed_Yes                  -0.007356             -0.006176
# readmitted_<30                   -0.005574             -0.006175
# readmitted_>30                    0.000433              0.008664
# readmitted_NO                     0.003107             -0.004386
#
#                       num_lab_procedures_9  num_lab_procedures_10  \
# encounter_id                      0.000793               0.016506
# patient_nbr                       0.021841               0.006187
# time_in_hospital                 -0.035003              -0.046510
# race_AfricanAmerican             -0.002929              -0.006165
# race_Asian                        0.005373               0.000992
# ...                                    ...                    ...
# diabetesMed_No                    0.010398               0.003433
# diabetesMed_Yes                  -0.010398              -0.003433
# readmitted_<30                   -0.000040              -0.000525
# readmitted_>30                   -0.008624              -0.003352
# readmitted_NO                     0.008274               0.003538
#
#                       num_lab_procedures_11  num_lab_procedures_12  \
# encounter_id                       0.011950               0.000725
# patient_nbr                        0.007324              -0.005501
# time_in_hospital                  -0.040176              -0.034369
# race_AfricanAmerican              -0.008592              -0.011965
# race_Asian                        -0.003544              -0.003862
# ...                                     ...                    ...
# diabetesMed_No                     0.002150               0.001539
# diabetesMed_Yes                   -0.002150              -0.001539
# readmitted_<30                    -0.003384              -0.001539
# readmitted_>30                    -0.002175              -0.005784
# readmitted_NO                      0.004218               0.006504
#
#                       num_lab_procedures_13  num_lab_procedures_14  \
# encounter_id                       0.019212               0.011603
# patient_nbr                        0.010707               0.011811
# time_in_hospital                  -0.029838              -0.023186
# race_AfricanAmerican              -0.008490              -0.006752
# race_Asian                         0.000899               0.008409
# ...                                     ...                    ...
# diabetesMed_No                     0.000406               0.002333
# diabetesMed_Yes                   -0.000406              -0.002333
# readmitted_<30                    -0.004509               0.001906
# readmitted_>30                    -0.004625              -0.008393
# readmitted_NO                      0.007272               0.006823
#
#                       num_lab_procedures_15  num_lab_procedures_16  \
# encounter_id                      -0.011163              -0.015308
# patient_nbr                       -0.014483              -0.015368
# time_in_hospital                  -0.021890              -0.024758
# race_AfricanAmerican              -0.005991              -0.013668
# race_Asian                        -0.005371              -0.004133
# ...                                     ...                    ...
# diabetesMed_No                     0.005906               0.000287
# diabetesMed_Yes                   -0.005906              -0.000287
# readmitted_<30                     0.002116               0.003120
# readmitted_>30                    -0.010749              -0.010461
# readmitted_NO                      0.008944               0.008035
#
#                       num_lab_procedures_17  num_lab_procedures_18  \
# encounter_id                      -0.040645              -0.028337
# patient_nbr                       -0.035382              -0.029055
# time_in_hospital                  -0.019922              -0.017712
# race_AfricanAmerican              -0.016592              -0.014818
# race_Asian                        -0.002451               0.005007
# ...                                     ...                    ...
# diabetesMed_No                    -0.004078               0.006398
# diabetesMed_Yes                    0.004078              -0.006398
# readmitted_<30                    -0.005835              -0.003871
# readmitted_>30                    -0.002546              -0.007810
# readmitted_NO                      0.006121               0.009914
#
#                       num_lab_procedures_19  num_lab_procedures_20  \
# encounter_id                      -0.005920              -0.007415
# patient_nbr                       -0.008707              -0.008828
# time_in_hospital                  -0.041621              -0.035342
# race_AfricanAmerican              -0.024574              -0.012525
# race_Asian                        -0.001470               0.006039
# ...                                     ...                    ...
# diabetesMed_No                     0.004627               0.011784
# diabetesMed_Yes                   -0.004627              -0.011784
# readmitted_<30                    -0.004811              -0.007290
# readmitted_>30                    -0.011256              -0.011111
# readmitted_NO                      0.013804               0.015232
#
#                       num_lab_procedures_21  num_lab_procedures_22  \
# encounter_id                       0.004207              -0.026265
# patient_nbr                        0.009396              -0.021021
# time_in_hospital                  -0.032407              -0.027432
# race_AfricanAmerican              -0.005443              -0.013426
# race_Asian                         0.004193               0.006986
# ...                                     ...                    ...
# diabetesMed_No                     0.014816               0.016571
# diabetesMed_Yes                   -0.014816              -0.016571
# readmitted_<30                     0.001367              -0.001687
# readmitted_>30                    -0.009417              -0.004609
# readmitted_NO                      0.008143               0.005474
#
#                       num_lab_procedures_23  num_lab_procedures_24  \
# encounter_id                      -0.046428              -0.036211
# patient_nbr                       -0.034255              -0.027056
# time_in_hospital                  -0.016595              -0.012002
# race_AfricanAmerican              -0.016360              -0.014574
# race_Asian                         0.002386               0.006289
# ...                                     ...                    ...
# diabetesMed_No                     0.010024               0.004085
# diabetesMed_Yes                   -0.010024              -0.004085
# readmitted_<30                    -0.001140              -0.002209
# readmitted_>30                    -0.010276              -0.007952
# readmitted_NO                      0.010548               0.009000
#
#                       num_lab_procedures_25  num_lab_procedures_26  \
# encounter_id                      -0.032588              -0.012143
# patient_nbr                       -0.012960              -0.013599
# time_in_hospital                  -0.011380              -0.030076
# race_AfricanAmerican              -0.027069               0.000119
# race_Asian                        -0.000740               0.001336
# ...                                     ...                    ...
# diabetesMed_No                    -0.002315              -0.006699
# diabetesMed_Yes                    0.002315               0.006699
# readmitted_<30                    -0.004314              -0.012132
# readmitted_>30                     0.008157              -0.001822
# readmitted_NO                     -0.005076               0.009406
#
#                       num_lab_procedures_27  num_lab_procedures_28  \
# encounter_id                      -0.006983               0.022142
# patient_nbr                        0.004105               0.027456
# time_in_hospital                  -0.026046              -0.035639
# race_AfricanAmerican              -0.004706              -0.006921
# race_Asian                         0.007958               0.004182
# ...                                     ...                    ...
# diabetesMed_No                    -0.004179              -0.006709
# diabetesMed_Yes                    0.004179               0.006709
# readmitted_<30                    -0.003377               0.004341
# readmitted_>30                    -0.000974              -0.001643
# readmitted_NO                      0.003065              -0.001171
#
#                       num_lab_procedures_29  num_lab_procedures_30  \
# encounter_id                       0.024740               0.027502
# patient_nbr                        0.006730               0.022291
# time_in_hospital                  -0.045963              -0.036521
# race_AfricanAmerican               0.004197              -0.001225
# race_Asian                         0.000610              -0.000573
# ...                                     ...                    ...
# diabetesMed_No                     0.010415               0.008075
# diabetesMed_Yes                   -0.010415              -0.008075
# readmitted_<30                    -0.003981               0.002150
# readmitted_>30                     0.000174               0.002532
# readmitted_NO                      0.002349              -0.003780
#
#                       num_lab_procedures_31  num_lab_procedures_32  \
# encounter_id                      -0.004926               0.008450
# patient_nbr                       -0.003400               0.003359
# time_in_hospital                  -0.032202              -0.032190
# race_AfricanAmerican              -0.000773              -0.003793
# race_Asian                         0.000818              -0.000453
# ...                                     ...                    ...
# diabetesMed_No                     0.005283               0.013286
# diabetesMed_Yes                   -0.005283              -0.013286
# readmitted_<30                    -0.000085              -0.005784
# readmitted_>30                    -0.002359               0.005498
# readmitted_NO                      0.002310              -0.001604
#
#                       num_lab_procedures_33  num_lab_procedures_34  \
# encounter_id                      -0.003106              -0.012619
# patient_nbr                        0.000897              -0.018064
# time_in_hospital                  -0.027134              -0.041787
# race_AfricanAmerican               0.002053               0.008174
# race_Asian                        -0.003510               0.001402
# ...                                     ...                    ...
# diabetesMed_No                    -0.001930               0.011618
# diabetesMed_Yes                    0.001930              -0.011618
# readmitted_<30                     0.000349              -0.003469
# readmitted_>30                     0.001650              -0.009511
# readmitted_NO                     -0.001799               0.011288
#
#                       num_lab_procedures_35  num_lab_procedures_36  \
# encounter_id                      -0.015639               0.000951
# patient_nbr                       -0.024823              -0.011739
# time_in_hospital                  -0.037777              -0.036794
# race_AfricanAmerican               0.022226               0.011622
# race_Asian                         0.006401              -0.000324
# ...                                     ...                    ...
# diabetesMed_No                     0.007310               0.002514
# diabetesMed_Yes                   -0.007310              -0.002514
# readmitted_<30                     0.000502               0.003414
# readmitted_>30                    -0.006092              -0.000193
# readmitted_NO                      0.005510              -0.001972
#
#                       num_lab_procedures_37  num_lab_procedures_38  \
# encounter_id                      -0.000232              -0.004475
# patient_nbr                       -0.009497              -0.026151
# time_in_hospital                  -0.030955              -0.026369
# race_AfricanAmerican               0.010039               0.026730
# race_Asian                        -0.003596              -0.005058
# ...                                     ...                    ...
# diabetesMed_No                     0.008236               0.009779
# diabetesMed_Yes                   -0.008236              -0.009779
# readmitted_<30                    -0.001768              -0.004701
# readmitted_>30                    -0.000606              -0.006778
# readmitted_NO                      0.001696               0.009452
#
#                       num_lab_procedures_39  num_lab_procedures_40  \
# encounter_id                      -0.005531               0.003967
# patient_nbr                       -0.014211              -0.010785
# time_in_hospital                  -0.019793              -0.013930
# race_AfricanAmerican               0.014905               0.013728
# race_Asian                        -0.000204               0.003532
# ...                                     ...                    ...
# diabetesMed_No                     0.007691               0.010408
# diabetesMed_Yes                   -0.007691              -0.010408
# readmitted_<30                    -0.003176              -0.001851
# readmitted_>30                     0.002342              -0.001243
# readmitted_NO                     -0.000234               0.002358
#
#                       num_lab_procedures_41  num_lab_procedures_42  \
# encounter_id                      -0.006870              -0.008820
# patient_nbr                       -0.017322              -0.018836
# time_in_hospital                  -0.016821              -0.014053
# race_AfricanAmerican               0.010272               0.010766
# race_Asian                        -0.004642              -0.005496
# ...                                     ...                    ...
# diabetesMed_No                     0.007224               0.003615
# ...
# readmitted_<30              0.003253           -0.003253           0.004430
# readmitted_>30              0.001417           -0.001417           0.002292
# readmitted_NO              -0.003410            0.003410          -0.004991
#
#                       pioglitazone_No  pioglitazone_Steady  pioglitazone_Up  \
# encounter_id                -0.046216             0.048143        -0.005268
# patient_nbr                 -0.039398             0.039755         0.000587
# time_in_hospital            -0.005466            -0.003666         0.035487
# race_AfricanAmerican         0.027129            -0.027411         0.000959
# race_Asian                   0.000076             0.000029        -0.001229
# ...                               ...                  ...              ...
# diabetesMed_No               0.152230            -0.148253        -0.026235
# diabetesMed_Yes             -0.152230             0.148253         0.026235
# readmitted_<30               0.005288            -0.006362         0.001880
# readmitted_>30              -0.015745             0.014961         0.004419
# readmitted_NO                0.011719            -0.010290        -0.005414
#
#                       rosiglitazone_Down  rosiglitazone_No  \
# encounter_id                   -0.008359          0.049807
# patient_nbr                    -0.002072          0.006802
# time_in_hospital                0.013578         -0.005731
# race_AfricanAmerican           -0.004659          0.007415
# race_Asian                     -0.002329          0.004663
# ...                                  ...               ...
# diabetesMed_No                 -0.015985          0.141157
# diabetesMed_Yes                 0.015985         -0.141157
# readmitted_<30                 -0.005028          0.005842
# readmitted_>30                 -0.005915         -0.015817
# readmitted_NO                   0.008834          0.011438
#
#                       rosiglitazone_Steady  rosiglitazone_Up  acarbose_Down  \
# encounter_id                     -0.047080         -0.015328      -0.000018
# patient_nbr                      -0.005924         -0.004313       0.005074
# time_in_hospital                 -0.000825          0.028401       0.001705
# race_AfricanAmerican             -0.007455          0.002644      -0.002619
# race_Asian                       -0.004407         -0.000360      -0.000432
# ...                                    ...               ...            ...
# diabetesMed_No                   -0.137996         -0.022875      -0.002967
# diabetesMed_Yes                   0.137996          0.022875       0.002967
# readmitted_<30                   -0.005227         -0.000646       0.003824
# readmitted_>30                    0.017747         -0.005018      -0.000182
# readmitted_NO                    -0.013672          0.005207      -0.002242
#
#                       acarbose_No  acarbose_Steady  acarbose_Up  \
# encounter_id             0.000542         0.000500    -0.005705
# patient_nbr             -0.011811         0.012042    -0.002638
# time_in_hospital        -0.006055         0.005583     0.002338
# race_AfricanAmerican     0.016978        -0.016668    -0.002249
# race_Asian              -0.000136         0.000328    -0.000789
# ...                           ...              ...          ...
# diabetesMed_No           0.030110        -0.029466    -0.005418
# diabetesMed_Yes         -0.030110         0.029466     0.005418
# readmitted_<30           0.003620        -0.004598     0.002783
# readmitted_>30          -0.017794         0.018004     0.001055
# readmitted_NO            0.014731        -0.014315    -0.002767
#
#                       miglitol_Down  miglitol_No  miglitol_Steady  \
# encounter_id               0.002426    -0.001529         0.000479
# patient_nbr               -0.000450    -0.006929         0.008307
# time_in_hospital          -0.001400    -0.001696         0.001268
# race_AfricanAmerican      -0.003381     0.001525        -0.001226
# race_Asian                -0.000558     0.001539        -0.001390
# ...                             ...          ...              ...
# diabetesMed_No            -0.003831     0.010562        -0.009540
# diabetesMed_Yes            0.003831    -0.010562         0.009540
# readmitted_<30             0.006420     0.000389        -0.002610
# readmitted_>30             0.003686    -0.007177         0.006109
# readmitted_NO             -0.007581     0.006619        -0.004194
#
#                       miglitol_Up  troglitazone_No  troglitazone_Steady  \
# encounter_id             0.000944         0.008678            -0.008678
# patient_nbr             -0.001792         0.001960            -0.001960
# time_in_hospital         0.004610        -0.003524             0.003524
# race_AfricanAmerican     0.003526         0.002619            -0.002619
# race_Asian              -0.000353         0.000432            -0.000432
# ...                           ...              ...                  ...
# diabetesMed_No          -0.002423         0.002967            -0.002967
# diabetesMed_Yes          0.002423        -0.002967             0.002967
# readmitted_<30          -0.001571         0.001924            -0.001924
# readmitted_>30           0.001402        -0.003615             0.003615
# readmitted_NO           -0.000348         0.002242            -0.002242
#
#                       tolazamide_No  tolazamide_Steady  tolazamide_Up  \
# encounter_id               0.018123          -0.017755      -0.003724
# patient_nbr                0.014644          -0.014166      -0.004128
# time_in_hospital           0.003102          -0.002905      -0.001466
# race_AfricanAmerican       0.000464          -0.000225      -0.001512
# race_Asian                 0.001559          -0.001539      -0.000250
# ...                             ...                ...            ...
# diabetesMed_No             0.010700          -0.010562      -0.001713
# diabetesMed_Yes           -0.010700           0.010562       0.001713
# readmitted_<30             0.002156          -0.002004      -0.001111
# readmitted_>30             0.003814          -0.004558       0.004279
# readmitted_NO             -0.005010           0.005626      -0.003390
#
#                       examide_No  citoglipton_No  insulin_Down  insulin_No  \
# encounter_id                 NaN             NaN      0.068434   -0.101159
# patient_nbr                  NaN             NaN      0.045309   -0.024453
# time_in_hospital             NaN             NaN      0.065110   -0.099043
# race_AfricanAmerican         NaN             NaN      0.010712   -0.046330
# race_Asian                   NaN             NaN     -0.003041    0.008602
# ...                          ...             ...           ...         ...
# diabetesMed_No               NaN             NaN     -0.201861    0.585464
# diabetesMed_Yes              NaN             NaN      0.201861   -0.585464
# readmitted_<30               NaN             NaN      0.032115   -0.033278
# readmitted_>30               NaN             NaN      0.030723   -0.024835
# readmitted_NO                NaN             NaN     -0.049670    0.044773
#
#                       insulin_Steady  insulin_Up  glyburide-metformin_Down  \
# encounter_id               -0.015834    0.112904                 -0.004701
# patient_nbr                -0.043004    0.054826                 -0.002927
# time_in_hospital           -0.007025    0.100104                  0.004555
# race_AfricanAmerican        0.039979    0.003987                 -0.000434
# race_Asian                 -0.010353    0.004632                 -0.000611
# ...                              ...         ...                       ...
# diabetesMed_No             -0.360434   -0.193296                 -0.004196
# diabetesMed_Yes             0.360434    0.193296                  0.004196
# readmitted_<30             -0.000660    0.020563                  0.001343
# readmitted_>30             -0.013139    0.026850                 -0.005626
# readmitted_NO               0.012984   -0.038669                  0.004532
#
#                       glyburide-metformin_No  glyburide-metformin_Steady  \
# encounter_id                       -0.034113                    0.035311
# patient_nbr                        -0.029791                    0.030949
# time_in_hospital                    0.002164                   -0.002124
# race_AfricanAmerican                0.007645                   -0.007219
# race_Asian                         -0.009806                    0.010037
# ...                                      ...                         ...
# diabetesMed_No                      0.045677                   -0.045218
# diabetesMed_Yes                    -0.045677                    0.045218
# readmitted_<30                      0.000297                   -0.000086
# readmitted_>30                     -0.002833                    0.003837
# readmitted_NO                       0.002522                   -0.003615
#
#                       glyburide-metformin_Up  glipizide-metformin_No  \
# encounter_id                       -0.003877               -0.000592
# patient_nbr                        -0.005439                0.003550
# time_in_hospital                   -0.004518                0.000626
# race_AfricanAmerican               -0.004277                0.005452
# race_Asian                         -0.000706                0.000900
# ...                                      ...                     ...
# diabetesMed_No                     -0.004846                0.006177
# diabetesMed_Yes                     0.004846               -0.006177
# readmitted_<30                     -0.003143                0.001245
# readmitted_>30                     -0.004171               -0.004485
# readmitted_NO                       0.005975                0.003503
#
#                       glipizide-metformin_Steady  glimepiride-pioglitazone_No  \
# encounter_id                            0.000592                    -0.002089
# patient_nbr                            -0.003550                     0.001050
# time_in_hospital                       -0.000626                     0.002516
# race_AfricanAmerican                   -0.005452                     0.001512
# race_Asian                             -0.000900                     0.000250
# ...                                          ...                          ...
# diabetesMed_No                         -0.006177                     0.001713
# diabetesMed_Yes                         0.006177                    -0.001713
# readmitted_<30                         -0.001245                     0.001111
# readmitted_>30                          0.004485                    -0.004279
# readmitted_NO                          -0.003503                     0.003390
#
#                       glimepiride-pioglitazone_Steady  \
# encounter_id                                 0.002089
# patient_nbr                                 -0.001050
# time_in_hospital                            -0.002516
# race_AfricanAmerican                        -0.001512
# race_Asian                                  -0.000250
# ...                                               ...
# diabetesMed_No                              -0.001713
# diabetesMed_Yes                              0.001713
# readmitted_<30                              -0.001111
# readmitted_>30                               0.004279
# readmitted_NO                               -0.003390
#
#                       metformin-rosiglitazone_No  \
# encounter_id                           -0.006630
# patient_nbr                            -0.009475
# time_in_hospital                        0.000588
# race_AfricanAmerican                    0.002138
# race_Asian                              0.000353
# ...                                          ...
# diabetesMed_No                          0.002423
# diabetesMed_Yes                        -0.002423
# readmitted_<30                          0.001571
# readmitted_>30                          0.003248
# readmitted_NO                          -0.004099
#
#                       metformin-rosiglitazone_Steady  \
# encounter_id                                0.006630
# patient_nbr                                 0.009475
# time_in_hospital                           -0.000588
# race_AfricanAmerican                       -0.002138
# race_Asian                                 -0.000353
# ...                                              ...
# diabetesMed_No                             -0.002423
# diabetesMed_Yes                             0.002423
# readmitted_<30                             -0.001571
# readmitted_>30                             -0.003248
# readmitted_NO                               0.004099
#
#                       metformin-pioglitazone_No  \
# encounter_id                          -0.007285
# patient_nbr                            0.001052
# time_in_hospital                      -0.001684
# race_AfricanAmerican                   0.001512
# race_Asian                             0.000250
# ...                                         ...
# diabetesMed_No                         0.001713
# diabetesMed_Yes                       -0.001713
# readmitted_<30                         0.001111
# readmitted_>30                         0.002297
# readmitted_NO                         -0.002898
#
#                       metformin-pioglitazone_Steady  change_Ch  change_No  \
# encounter_id                               0.007285   0.096372  -0.096372
# patient_nbr                               -0.001052   0.054842  -0.054842
# time_in_hospital                           0.001684   0.109173  -0.109173
# race_AfricanAmerican                      -0.001512  -0.007610   0.007610
# race_Asian                                -0.000250  -0.004263   0.004263
# ...                                             ...        ...        ...
# diabetesMed_No                            -0.001713  -0.506370   0.506370
# diabetesMed_Yes                            0.001713   0.506370  -0.506370
# readmitted_<30                            -0.001111   0.019506  -0.019506
# readmitted_>30                            -0.002297   0.035221  -0.035221
# readmitted_NO                              0.002898  -0.046008   0.046008
#
#                       diabetesMed_No  diabetesMed_Yes  readmitted_<30  \
# encounter_id               -0.051817         0.051817       -0.008519
# patient_nbr                -0.017232         0.017232        0.007893
# time_in_hospital           -0.062520         0.062520        0.044199
# race_AfricanAmerican       -0.000340         0.000340        0.000892
# race_Asian                  0.005487        -0.005487       -0.002578
# ...                              ...              ...             ...
# diabetesMed_No              1.000000        -1.000000       -0.027125
# diabetesMed_Yes            -1.000000         1.000000        0.027125
# readmitted_<30             -0.027125         0.027125        1.000000
# readmitted_>30             -0.046396         0.046396       -0.259667
# readmitted_NO               0.061508        -0.061508       -0.383331
#
#                       readmitted_>30  readmitted_NO
# encounter_id               -0.034384       0.038267
# patient_nbr                 0.072256      -0.074093
# time_in_hospital            0.024434      -0.051289
# race_AfricanAmerican       -0.003987       0.003250
# race_Asian                 -0.016385       0.017299
# ...                              ...            ...
# diabetesMed_No             -0.046396       0.061508
# diabetesMed_Yes             0.046396      -0.061508
# readmitted_<30             -0.259667      -0.383331
# readmitted_>30              1.000000      -0.792391
# readmitted_NO              -0.792391       1.000000
#
# [2723 rows x 2723 columns]

# %% [markdown]
# After one hot enconding we transformed the dataset to 2723 features from 49 features and one target variable.

# %%
# Set the correlation threshold
correlation_threshold = 0.10

# Create a list to store DataFrames for significant correlations
significant_correlations = []

# Iterate through all features
for feature in encoded_df.columns:
    if feature.startswith('readmitted_'):
        continue  # Skip target variables
    
    # Filter correlations for the current feature
    feature_correlations = correlations[feature]
    filtered_correlations = feature_correlations[
        (feature_correlations.index.str.startswith('readmitted_')) & (abs(feature_correlations) >= correlation_threshold)
    ]

    # Create a DataFrame for significant correlations
    feature_results = pd.DataFrame({'Feature': [feature] * len(filtered_correlations.index),
                                    'Target Variable': filtered_correlations.index,
                                    'Correlation': filtered_correlations.values})
    
    # Append to the list of significant_correlations DataFrames
    significant_correlations.append(feature_results)

# Concatenate all DataFrames in the list
result_df = pd.concat(significant_correlations, ignore_index=True)

# Display the significant correlations as a table
print(result_df)
# Out:
#                        Feature Target Variable  Correlation
# 0  discharge_disposition_id_11   readmitted_NO     0.118405
# 1          number_outpatient_0   readmitted_NO     0.110199
# 2           number_emergency_0   readmitted_NO     0.124014
# 3           number_inpatient_0  readmitted_<30    -0.121716
# 4           number_inpatient_0  readmitted_>30    -0.143798
# 5           number_inpatient_0   readmitted_NO     0.214417
# 6           number_inpatient_2   readmitted_NO    -0.107156

# %% [markdown]
# The correlation matrix towards the target variables indicate weak correlations across the board with the highest correlation among the features being number_inpatient_0 to readmitted_No target variable at 0.2144 indicating that if a patient is not inpatient then they are more likely not to be readmiatted to the hospitable. We see an inverse relationship between the other two target variables and number_inpatient_0 reinforcing the previous observation that if not an inpatient then unlikely to be readmitted. For disposition_id_11 or an Expired the patient is likely to not be readmitted.

# %% [markdown]
# ### Examine the correlations among the features

# %%
#set the correlation threshold
threshold = 0.90

#Create empty lists to store strong relationships 
strong_pos_corr = []
strong_neg_corr = []

# Iterate through the correlation matrix
for feature1 in correlations.columns:
    for feature2 in correlations.index:
        if feature1 !=feature2: # Avoid comparing a feature with itself
            corr_value = correlations.loc[feature2, feature1]
            if corr_value > threshold:
                strong_pos_corr.append((feature2, feature1, corr_value))
            elif corr_value < -threshold:
                strong_neg_corr.append((feature2, feature1, corr_value))

                
# Sort the correlations alphabetically
strong_pos_corr.sort()
strong_neg_corr.sort()
                
# Format results as table
pos_table = tabulate(strong_pos_corr, headers=["Feature 1", "Feature 2", "Correlation"], tablefmt="grid")
neg_table = tabulate(strong_neg_corr, headers=["Feature 1", "Feature 2", "Correlation"], tablefmt="grid")

#Display strong pos correlations
print("Strong Positive Correlations:")
print(pos_table)

print()

#Display strong pos correlations
print("Strong Negative Correlations:")
print(neg_table)
# Out:
# Strong Positive Correlations:
# +-------------+-------------+---------------+
# | Feature 1   | Feature 2   |   Correlation |
# +=============+=============+===============+
# | diag_1_10   | diag_3_14   |             1 |
# +-------------+-------------+---------------+
# | diag_1_98   | diag_2_99   |             1 |
# +-------------+-------------+---------------+
# | diag_2_947  | diag_3_E861 |             1 |
# +-------------+-------------+---------------+
# | diag_2_948  | diag_3_E894 |             1 |
# +-------------+-------------+---------------+
# | diag_2_99   | diag_1_98   |             1 |
# +-------------+-------------+---------------+
# | diag_3_14   | diag_1_10   |             1 |
# +-------------+-------------+---------------+
# | diag_3_E861 | diag_2_947  |             1 |
# +-------------+-------------+---------------+
# | diag_3_E894 | diag_2_948  |             1 |
# +-------------+-------------+---------------+
#
# Strong Negative Correlations:
# +---------------------------------+---------------------------------+---------------+
# | Feature 1                       | Feature 2                       |   Correlation |
# +=================================+=================================+===============+
# | acarbose_No                     | acarbose_Steady                 |     -0.978606 |
# +---------------------------------+---------------------------------+---------------+
# | acarbose_Steady                 | acarbose_No                     |     -0.978606 |
# +---------------------------------+---------------------------------+---------------+
# | acetohexamide_No                | acetohexamide_Steady            |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | acetohexamide_Steady            | acetohexamide_No                |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | change_Ch                       | change_No                       |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | change_No                       | change_Ch                       |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | chlorpropamide_No               | chlorpropamide_Steady           |     -0.958406 |
# +---------------------------------+---------------------------------+---------------+
# | chlorpropamide_Steady           | chlorpropamide_No               |     -0.958406 |
# +---------------------------------+---------------------------------+---------------+
# | diabetesMed_No                  | diabetesMed_Yes                 |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | diabetesMed_Yes                 | diabetesMed_No                  |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | gender_Female                   | gender_Male                     |     -0.999941 |
# +---------------------------------+---------------------------------+---------------+
# | gender_Male                     | gender_Female                   |     -0.999941 |
# +---------------------------------+---------------------------------+---------------+
# | glimepiride-pioglitazone_No     | glimepiride-pioglitazone_Steady |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | glimepiride-pioglitazone_Steady | glimepiride-pioglitazone_No     |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | glimepiride_No                  | glimepiride_Steady              |     -0.945942 |
# +---------------------------------+---------------------------------+---------------+
# | glimepiride_Steady              | glimepiride_No                  |     -0.945942 |
# +---------------------------------+---------------------------------+---------------+
# | glipizide-metformin_No          | glipizide-metformin_Steady      |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | glipizide-metformin_Steady      | glipizide-metformin_No          |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | glipizide_No                    | glipizide_Steady                |     -0.939144 |
# +---------------------------------+---------------------------------+---------------+
# | glipizide_Steady                | glipizide_No                    |     -0.939144 |
# +---------------------------------+---------------------------------+---------------+
# | glyburide-metformin_No          | glyburide-metformin_Steady      |     -0.989967 |
# +---------------------------------+---------------------------------+---------------+
# | glyburide-metformin_Steady      | glyburide-metformin_No          |     -0.989967 |
# +---------------------------------+---------------------------------+---------------+
# | glyburide_No                    | glyburide_Steady                |     -0.926198 |
# +---------------------------------+---------------------------------+---------------+
# | glyburide_Steady                | glyburide_No                    |     -0.926198 |
# +---------------------------------+---------------------------------+---------------+
# | metformin-pioglitazone_No       | metformin-pioglitazone_Steady   |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | metformin-pioglitazone_Steady   | metformin-pioglitazone_No       |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | metformin-rosiglitazone_No      | metformin-rosiglitazone_Steady  |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | metformin-rosiglitazone_Steady  | metformin-rosiglitazone_No      |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | metformin_No                    | metformin_Steady                |     -0.94857  |
# +---------------------------------+---------------------------------+---------------+
# | metformin_Steady                | metformin_No                    |     -0.94857  |
# +---------------------------------+---------------------------------+---------------+
# | miglitol_No                     | miglitol_Steady                 |     -0.90318  |
# +---------------------------------+---------------------------------+---------------+
# | miglitol_Steady                 | miglitol_No                     |     -0.90318  |
# +---------------------------------+---------------------------------+---------------+
# | nateglinide_No                  | nateglinide_Steady              |     -0.97462  |
# +---------------------------------+---------------------------------+---------------+
# | nateglinide_Steady              | nateglinide_No                  |     -0.97462  |
# +---------------------------------+---------------------------------+---------------+
# | pioglitazone_No                 | pioglitazone_Steady             |     -0.973874 |
# +---------------------------------+---------------------------------+---------------+
# | pioglitazone_Steady             | pioglitazone_No                 |     -0.973874 |
# +---------------------------------+---------------------------------+---------------+
# | repaglinide_No                  | repaglinide_Steady              |     -0.947574 |
# +---------------------------------+---------------------------------+---------------+
# | repaglinide_Steady              | repaglinide_No                  |     -0.947574 |
# +---------------------------------+---------------------------------+---------------+
# | rosiglitazone_No                | rosiglitazone_Steady            |     -0.977605 |
# +---------------------------------+---------------------------------+---------------+
# | rosiglitazone_Steady            | rosiglitazone_No                |     -0.977605 |
# +---------------------------------+---------------------------------+---------------+
# | tolazamide_No                   | tolazamide_Steady               |     -0.987091 |
# +---------------------------------+---------------------------------+---------------+
# | tolazamide_Steady               | tolazamide_No                   |     -0.987091 |
# +---------------------------------+---------------------------------+---------------+
# | tolbutamide_No                  | tolbutamide_Steady              |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | tolbutamide_Steady              | tolbutamide_No                  |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | troglitazone_No                 | troglitazone_Steady             |     -1        |
# +---------------------------------+---------------------------------+---------------+
# | troglitazone_Steady             | troglitazone_No                 |     -1        |
# +---------------------------------+---------------------------------+---------------+

# %% [markdown]
# From the correlation table, we can see that the certain diagnosis have a perfect correlation to a 2nd & 3rd diagnosis. Indicating that if a patient has been diagnosised with 10 they will also be diagnosied with 14.  Simultanseoulsy, if the first diagnosis of 98 the second will be 99. Should the second diagnosis be 947 then the third will be E861. This trend continues with other perfectly correlated feature pairs. To note on negatively correlated features, only those that are among the same original categorical feature are inversely correlated to one another. If diabetesMed_No is marked then diabetesMed_Yes will not be marked. This associating continues among other features.

# %% [markdown]
# ## Explore Attributes and Class
# Identify and explain interesting relationships between features and the class you are trying to predict (i.e., relationships with variables and the target classification).

# %% [markdown]
# In this section we want to explore the relationship of minutes delayed when grouping by airline, month, and day of the month. Until we complete the regression and classification portion of our analysis, we won't be able to give hard numbers into the weight of each of these categorical variables. However, this section can show us some fast information about airlines, months, or days of the month to avoid flying.

# %% [markdown]
# # Modeling

# %%
##Multi-Nomial Regression with Distance Group/ EXCEPTIONAL WORK
#encoded_df

# Create a target variable with three levels: 0, 1, and 2
encoded_df['target'] = encoded_df['readmitted_<30'].astype(int) + encoded_df['readmitted_>30'].astype(int) * 2


#split the data into features x and features y
x = encoded_df.drop(columns=['readmitted_<30', 'readmitted_>30', 'readmitted_NO'])
y = encoded_df[['target']]

#split the dataset into train test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=10)

# Reshape y_train and y_test
y_train = np.ravel(y_train)
y_test = np.ravel(y_test)

# %%
# create the model the model
model = LogisticRegression(multi_class='multinomial')

# %%
# create hyperparamater grid
param_grid = {
    'C': [0.001, 0.01, 0.1, 1.0, 10.0],  # Inverse of regularization strength
}

# %%
#preform the grid search
grid_search = GridSearchCV(model, param_grid, cv=5, verbose=2, n_jobs=-1)

grid_search.fit(x_train,y_train)


# Get the best parameters from the grid search
best_params = grid_search.best_params_
print("Best Parameters:")
print(best_params)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
#
#
# 8 fits failed out of a total of 25.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1508, in fit
#     X, y = self._validate_data(
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 964, in check_X_y
#     X = check_array(
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 746, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\pandas\core\generic.py", line 1781, in __array__
#     return np.asarray(self._values, dtype=dtype)
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 1.32 GiB for an array with shape (65130, 2721) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1508, in fit
#     X, y = self._validate_data(
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 964, in check_X_y
#     X = check_array(
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 746, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\pandas\core\generic.py", line 1781, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\pandas\core\generic.py", line 5348, in _values
#     return self.values
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\pandas\core\generic.py", line 5343, in values
#     return self._mgr.as_array(transpose=self._AXIS_REVERSED)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\pandas\core\internals\managers.py", line 853, in as_array
#     arr = self._interleave(dtype=dtype, na_value=na_value)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\pandas\core\internals\managers.py", line 882, in _interleave
#     result = np.empty(self.shape, dtype=dtype)
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 1.32 GiB for an array with shape (2721, 65130) and data type int64
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1508, in fit
#     X, y = self._validate_data(
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 964, in check_X_y
#     X = check_array(
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 746, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\pandas\core\generic.py", line 1781, in __array__
#     return np.asarray(self._values, dtype=dtype)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\pandas\core\generic.py", line 5348, in _values
#     return self.values
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\pandas\core\generic.py", line 5343, in values
#     return self._mgr.as_array(transpose=self._AXIS_REVERSED)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\pandas\core\internals\managers.py", line 853, in as_array
#     arr = self._interleave(dtype=dtype, na_value=na_value)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\pandas\core\internals\managers.py", line 882, in _interleave
#     result = np.empty(self.shape, dtype=dtype)
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 1.32 GiB for an array with shape (2721, 65129) and data type int64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1508, in fit
#     X, y = self._validate_data(
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\base.py", line 581, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 964, in check_X_y
#     X = check_array(
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 746, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "C:\Users\rwbut\anaconda3\lib\site-packages\pandas\core\generic.py", line 1781, in __array__
#     return np.asarray(self._values, dtype=dtype)
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 1.32 GiB for an array with shape (65129, 2721) and data type float64
#
#
# C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning:
#
# One or more of the test scores are non-finite: [       nan        nan        nan        nan 0.54199634]
# Best Parameters:
# {'C': 0.001}

# %%
# Get the best model from the grid search
best_logistic_regression_model = grid_search.best_estimator_

# Make predictions on the test data using the best model
y_pred = best_logistic_regression_model.predict(x_test)

# %%
# Evaluate the model
classification_report_result = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(classification_report_result)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.90      0.69     10992
#            1       0.00      0.00      0.00      2364
#            2       0.43      0.15      0.22      6998
#
#     accuracy                           0.54     20354
#    macro avg       0.33      0.35      0.30     20354
# weighted avg       0.45      0.54      0.45     20354
# C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# C:\Users\rwbut\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# From the output above we can see the logistic regression for classifying Distance group is highly accurate. Looking at the Confusion Matrix below, we see there is a difference not only with the implementation of K-Fold Cross Validation, but also with the addition of the L2 Penalty. We are more confident in the models without the L2 penalty as these classify more accurately as well as provide enough room to provide post model adjustments if need be. This is our first attempt at modeling with our Flight dataset and in the future will bring about more robust methods to our modeling. Upon further review of the model, there are many more directions available for us to entertain, but would require a more in depth understanding of modeling within Pandas.

# %%
print(y_train[y_train == 1].count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-65b72c8736ed> in <module>
# ----> 1 print(y_train[y_train == 1].count)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
# Convert y_train and y_test to pandas Series (assuming they are numpy arrays)
y_train_series = pd.Series(y_train.ravel())
y_test_series = pd.Series(y_test.ravel())

# Count the occurrences of each value and get the count for 1
count_train = y_train_series.value_counts().get(1, 0)
count_test = y_test_series.value_counts().get(1, 0)

print("Number of 1s in y_train:", count_train)
print("Number of 1s in y_test:", count_test)
# Out:
# Number of 1s in y_train: 8993
# Number of 1s in y_test: 2364
